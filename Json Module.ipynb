# %%
import json
data = {"name" : "rhushi", "age" : 22, "city" : "chiplun"}
json_string = json.dumps(data)
print(json_string)
print(type(json_string))
# Out:
# {"name": "rhushi", "age": 22, "city": "chiplun"}
# <class 'str'>

# %%
py_obj = json.loads(json_string)
print(py_obj)
print(type(py_obj))
# Out:
# {'name': 'rhushi', 'age': 22, 'city': 'chiplun'}
# <class 'dict'>
