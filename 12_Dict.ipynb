# %%
a = {
    "name" : "rhushi",
    "age" : 22,
    "grade" : "A"
}
a
# Out:
# {'name': 'rhushi', 'age': 22, 'grade': 'A'}

# %%
print(a["name"])
# Out:
# rhushi

# %%
for key, value in a.items():
    print(key, ":", value)
# Out:
# name : rhushi
# age : 22
# grade : A
