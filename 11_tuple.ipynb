# %%
a = (1,2,3,4,5)
a
# Out:
# (1, 2, 3, 4, 5)

# %%
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
#packing and unpacking 
b = ("Alice", 25,"engineering")

name, age, profession = b
print(name)
print(age)
print(profession)
# Out:
# Alice
# 25
# engineering
