# %%
file = open("text.txt", "r")
content = file.read()
print(content)
line = file.readline()
print(line)
# Out:
# rhushikesh chiplunkar
# ritikesh chiplunkar

# %%
file.close()

# %%
print(content)
# Out:
# rhushikesh chiplunkar

# %%
file = open("text2.txt", "w")
file.write("rhushi")
file.close()
file = open("text2.txt", "r")
c = file.readlines()
print(c)
# Out:
# ['rhushi']

# %%
lines = ["Hello\n", "Welcome to Python\n", "File Handling\n"]
file = open("example.txt", "w")
file.writelines(lines) # Writes multiple lines
file.close()

# %%
with open("text.txt", "r") as file:
    b = file.readlines()
    print(b)
# Out:
# []
