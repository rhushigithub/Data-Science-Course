# %%
a = [1,2,3,4,5,6]
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b = [1,2, "rhushi",3,4]
b
# Out:
# [1, 2, 'rhushi', 3, 4]

# %%
a.append(10)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 10]

# %%
c = a.copy()

# %%
c
# Out:
# [1, 2, 3, 4, 5, 6, 10]
